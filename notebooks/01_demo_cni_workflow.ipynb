# %% [markdown]
# # Demo CNI Workflow
# This notebook demonstrates how the Community Need Index is calculated using demo data.

# %%
import sys
sys.path.append('..')
from src.demo_data import load_demo_data
from src.cni_model import calculate_cni
from src.recommendation_engine import attach_recommendations

df = load_demo_data()
result = attach_recommendations(calculate_cni(df))
result.head()
